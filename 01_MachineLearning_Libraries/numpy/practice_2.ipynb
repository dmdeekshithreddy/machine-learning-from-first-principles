# %%
import numpy as np

# %%
A = np.array([[-1, 3], [3, 2]], dtype=np.float64)
b = np.array([7, 1], dtype=np.float64)

print(f"A.ndim = {A.ndim}")
print(f"b.ndim = {b.ndim}")

print(f"A.shape = {A.shape}")
print(f"b.shape = {b.shape}")

print("Matrix A:")
print(A)
print("\nArray b:")
print(b)
# Out:
# A.ndim = 2
# b.ndim = 1
# A.shape = (2, 2)
# b.shape = (2,)
# Matrix A:
# [[-1.  3.]
#  [ 3.  2.]]
#
# Array b:
# [7. 1.]

# %%
x = np.linalg.solve(A, b)
print(x)
# Out:
# [-1.  2.]

# %%
# to find the determinant of a matrix

det_of_A = np.linalg.det(A)
print(f"Determinant of matrix A: {det_of_A: .2f}")
# Out:
# Determinant of matrix A: -11.00

# %%
-1 * x[0] + 3 * x[1]  # should be 7
# Out:
# 7.000000000000001

# %%
a1 = np.array([1, 2])
print(a1.shape)  # (2,)
print(a1)
# Out:
# (2,)
# [1 2]

# %%
a2 = a1.reshape((2, 1))
print(a2.shape)  # (2, 1)
print(a2)
# Out:
# (2, 1)
# [[1]
#  [2]]
