# %% [markdown]
# inputs to the below function are <br>
# - current line equation -  need this to predict the price; to calculate it we need slope, y-intercept, feature (number of rooms)
# - actual price,
# - learning rate

# %%
def square_trick(learning_rate, price_per_room, base_price, number_of_rooms, actual_price):
    predicted_price = price_per_room * number_of_rooms + base_price
    error = actual_price - predicted_price
    new_base_price = base_price + (learning_rate * error)
    new_price_per_room = price_per_room + (learning_rate * number_of_rooms * error)
    return new_base_price, new_price_per_room

# %%
# Input: is a point in the plane (number_of_rooms, actual_price)
# trainable parameters: base_price, price_per_room

from sklearn import base


def square_trick_practice_two(number_of_rooms, actual_price, base_price, price_per_room, learning_rate):
    predicted_price = price_per_room * number_of_rooms + base_price
    error = actual_price - predicted_price
    base_price += learning_rate * error
    price_per_room += learning_rate * number_of_rooms * error
    return base_price, price_per_room
